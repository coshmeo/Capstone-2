# %% [markdown]
# # Exploratory Data Analysis
# note: how to access year in datetime obj
#
# import datetime
#
# year = datetime.datetime.today().year

# %% [markdown]
# ## Pull data from raw files

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

sns.set()

# %%
#historical stock data
amzn = pd.read_csv('raw data/amzn.csv', index_col = 0)
aapl = pd.read_csv('raw data/apple.csv', index_col = 0)
goog = pd.read_csv('raw data/google.csv', index_col = 0)
msft = pd.read_csv('raw data/msft.csv', index_col = 0)
#technical indicators
ma7 = pd.read_csv('raw data/msft_ma7.csv', index_col = 0)
ma21 = pd.read_csv('raw data/msft_ma21.csv', index_col = 0)
bbands = pd.read_csv('raw data/msft_bbands.csv', index_col = 0)
macd = pd.read_csv('raw data/msft_macd.csv', index_col = 0)
#indicies
nasdaq = pd.read_csv('raw data/^IXIC.csv', index_col = 0)
nyse = pd.read_csv('raw data/^NYA.csv', index_col = 0)
sp500 = pd.read_csv('raw data/^GSPC.csv', index_col = 0)
tb13 = pd.read_csv('raw data/^IRX.csv', index_col = 0)

#normalized data
amzn_norm = pd.read_csv('normalized data/amzn.csv', index_col = 0)
aapl_norm = pd.read_csv('normalized data/apple.csv', index_col = 0)
goog_norm = pd.read_csv('normalized data/google.csv', index_col = 0)
msft_norm = pd.read_csv('normalized data/msft.csv', index_col = 0)

nasdaq_norm = pd.read_csv('normalized data/nasdaq.csv', index_col = 0)
nyse_norm = pd.read_csv('normalized data/nyse.csv', index_col = 0)
sp500_norm = pd.read_csv('normalized data/sp500.csv', index_col = 0)
tb13_norm = pd.read_csv('normalized data/tb13.csv', index_col = 0)

# %% [markdown]
# ## Create plots

# %%
#microsoft
plt.figure(figsize=(15,6))
#historical stock data
plt.plot(msft['4. close'])
#add bollinger bands data
plt.fill_between(bbands.index, #x values
                 bbands.iloc[:,0].values, #lower bound
                 bbands.iloc[:,2].values, #upper bound
                 alpha=0.2, color = 'blue') 
#7 day moving average
plt.plot(ma7, linestyle = '--')
#21 day moving average
plt.plot(ma21, linestyle = '-.')
plt.title('Microsoft Stock Price')
plt.xticks(np.arange(0,2264, 250), np.arange(2010, 2020))
plt.xlabel('Time')
plt.ylabel('Price (USD)')

#add legend
blue_patch = mpatches.Patch(color='blue', label='Microsoft Stock')
bands = mpatches.Patch(color='blue', label='Bollinger Bands', alpha = 0.2)
green_patch = mpatches.Patch(color = 'green', label = '7 Day Moving Average')
orange_patch = mpatches.Patch(color = 'orange', label = '21 Day Moving Average')
plt.legend(handles=[blue_patch, bands, green_patch, orange_patch])

plt.show()

# %%
#Fourier transforms for MSFT stock
close_fft = np.fft.fft(np.asarray(msft['5. adjusted close'].tolist()))
fft_df = pd.DataFrame({'fft':close_fft})
plt.figure(figsize=(15, 6))
fft_list = np.asarray(fft_df['fft'].tolist())
for num_ in [3, 6, 9, 100]:
    fft_list_m10= np.copy(fft_list); fft_list_m10[num_:-num_]=0
    plt.plot(np.fft.ifft(fft_list_m10), label='Fourier transform with {} components'.format(num_))
plt.plot(msft['5. adjusted close'],  label='Real')
plt.legend()
plt.xticks(np.arange(0, 2263, 250), np.arange(2010,2020))
plt.title('Fourier Transforms on Microsoft stock with 3, 6, 9, and 100 components')
plt.ylabel('Price (USD)')
plt.xlabel('Time')
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:538: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
#Microsoft MACD
plt.figure(figsize=(15,6))
plt.plot(macd['MACD'])
plt.plot(macd['MACD_Signal'])
plt.title('Microsoft MACD')
plt.xticks(np.arange(0,2264, 250), np.arange(2010, 2020))
plt.xlabel('Time')
plt.ylabel('MACD Value')
plt.legend()
plt.show()

# %%
#amazon
plt.figure(figsize=(15,6))
plt.plot(amzn['5. adjusted close'])
plt.title('Amazon Stock Price')
plt.xticks(np.arange(0,2264, 250), np.arange(2010, 2020))
plt.xlabel('Time')
plt.ylabel('Price (USD)')
plt.show()

# %%
#apple
plt.figure(figsize=(15,6))
plt.plot(aapl['5. adjusted close'])
plt.title('Apple Stock Price')
plt.xticks(np.arange(0,2264, 250), np.arange(2010, 2020))
plt.xlabel('Time')
plt.ylabel('Price (USD)')
plt.show()

# %%
#google
plt.figure(figsize=(15,6))
plt.plot(goog['5. adjusted close'])
plt.title('Google Stock Price')
plt.xticks(np.arange(0,2264, 250), np.arange(2010, 2020))
plt.xlabel('Time')
plt.ylabel('Price (USD)')
plt.show()

# %%
#nasdaq index
plt.figure(figsize=(15,6))
plt.plot(nasdaq['Adj Close'])
plt.title('Nasdaq Index')
plt.xticks(np.arange(0,2264, 250), np.arange(2010, 2020))
plt.xlabel('Time')
plt.ylabel('Price (USD)')
plt.show()

# %%
#new york stock exchange index
plt.figure(figsize=(15,6))
plt.plot(nyse['Adj Close'])
plt.title('New York Stock Exchange Index')
plt.xticks(np.arange(0,2264, 250), np.arange(2010, 2020))
plt.xlabel('Time')
plt.ylabel('Price (USD)')
plt.show()

# %%
#S&P 500 index
plt.figure(figsize=(15,6))
plt.plot(sp500['Adj Close'])
plt.title('S&P 500 Index')
plt.xticks(np.arange(0,2264, 250), np.arange(2010, 2020))
plt.xlabel('Time')
plt.ylabel('Price (USD)')
plt.show()

# %%
#13 year treasury bond
plt.figure(figsize=(15,6))
plt.plot(tb13['Adj Close'])
plt.title('13 Year Treasury Bond Price')
plt.xticks(np.arange(0,2264, 250), np.arange(2010, 2020))
plt.xlabel('Time')
plt.ylabel('Interest rate (%)')
plt.show()

# %% [markdown]
# ## Plot normalized data

# %%
nasdaq_norm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2264 entries, 2010-01-04 to 2018-12-31
# Data columns (total 6 columns):
# Open         2264 non-null float64
# High         2264 non-null float64
# Low          2264 non-null float64
# Close        2264 non-null float64
# Adj Close    2264 non-null float64
# Volume       2264 non-null float64
# dtypes: float64(6)
# memory usage: 123.8+ KB

# %%
data = [amzn_norm['5. adjusted close'], 
        aapl_norm['5. adjusted close'], 
        goog_norm['5. adjusted close'], 
        msft_norm['5. adjusted close'], 
        nasdaq_norm['Adj Close'], 
        nyse_norm['Adj Close'], 
        sp500_norm['Adj Close'], 
        tb13_norm['Adj Close']]

# %%
plt.figure(figsize=(15,6))

for stock in range(len(data)):
    plt.plot(data[stock])

plt.title('Scaled Data')
plt.xticks(np.arange(0,2264, 250), np.arange(2010, 2020))
plt.xlabel('Time')
plt.ylabel('Price')

#add custom legend
palette = sns.color_palette('deep', 8) #set palette colors

blue_patch = mpatches.Patch(color=palette[0], label='AMZN')
orange_patch = mpatches.Patch(color=palette[1], label='AAPL')
green_patch = mpatches.Patch(color = palette[2], label = 'GOOGL')
red_patch = mpatches.Patch(color = palette[3], label = 'MSFT')
purple_patch = mpatches.Patch(color = palette[4], label = '^IXIC (Nasdaq)')
brown_patch = mpatches.Patch(color = palette[5], label = '^NYA (NYSE)')
pink_patch = mpatches.Patch(color = palette[6], label = '^GSPC (S&P 500)')
gray_patch = mpatches.Patch(color = palette[7], label = '^IRX (13 Week Treasury Bill Interest Rate)')


plt.legend(handles=[blue_patch, orange_patch, green_patch, red_patch, purple_patch,
                   brown_patch, pink_patch, gray_patch])

plt.show()
